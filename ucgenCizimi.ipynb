# %%
"""
fonksiyonlar
def(*required)
return 
"""
#Parametresizfonksiyonlar
# Out:
# f

# %%
rows = 5
for i in range(rows+1):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
rows = 5
for i in range(rows+1,0,-1):
    print("*"*i)
# Out:
# ******
# *****
# ****
# ***
# **
# *

# %%
rows = 5
for i in range(1,rows+1):
    print(" "*(rows-i) + "*"*i*2)
# Out:
#     **
#    ****
#   ******
#  ********
# **********

# %%
rows = 5
for i in range(rows,0,-1):
    for j in range(i):
        if j == 0:
            print(" "*(rows-i)+ "*"*2, end="")
        else:
         print("*"*2, end="")
    print()
# Out:
# **********
#  ********
#   ******
#    ****
#     **

# %%
rows = 5
for i in range(1,rows+1):
    print("*"* i + " "*(rows-i)*2 + "*"*i )
# Out:
# *        *
# **      **
# ***    ***
# ****  ****
# **********
